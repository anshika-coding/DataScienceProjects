# %% [markdown]
# ## <b>COVID-19 UnEmployment Analysis<b>

# %% [markdown]
# ### <u><b>Project Description:<b><u>
# **This project focuses on analyzing unemployment rate data to understand trends and patterns in unemployment over time. Using Python, the dataset is cleaned, explored, and visualized to highlight significant changes, including the impact of Covid-19. The analysis aims to uncover seasonal patterns, economic shifts, and other factors affecting unemployment, providing insights that can guide economic or social policy decisions. 📊**

# %% [markdown]
# ### <u><b>Objectives:<b><u>
# - **Collect and clean unemployment rate data for analysis.**
# - **Explore and visualize trends and patterns in unemployment over time.**
# - **Assess the impact of Covid-19 on unemployment rates.**
# - **Identify seasonal and economic patterns influencing unemployment.**
# - **Generate actionable insights to support policy-making and economic planning.**

# %% [markdown]
# <b>:- We import essential Python libraries for data analysis and visualization. NumPy is used for numerical operations and array handling, while pandas helps in data manipulation, cleaning, and analysis. Matplotlib.pyplot is used to create basic static plots and charts, and Seaborn provides advanced, visually appealing statistical plots that make it easier to explore and understand trends in the data.<b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### <b>:- Here, we’re loading our unemployment data into Python so we can start exploring it. The first file has general unemployment information across different states, while the second file gives monthly unemployment rates up to November 2020, capturing the effects of COVID-19. With these datasets, we can clean the data, spot trends, and visualize how unemployment has changed over time.<b>

# %%
unemp = pd.read_csv("C:\\Users\\Asus\\Documents\\Internship\\Code alpha\\Unemployment Analysis\\Unemployment_data\\Unemployment_in_India.csv")
unemp_rate = pd.read_csv("C:\\Users\\Asus\\Documents\\Internship\\Code alpha\\Unemployment Analysis\\Unemployment_data\\Unemployment_Rate_upto_11_2020.csv")

# %%
unemp
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
unemp_rate
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# ### <b>:- Now, we’re going to take a closer look at our data to understand it better. We’ll check the size of the dataset with .shape, peek at the first few rows with .head(), inspect data types and missing values using .info(), and get a quick statistical summary with .describe(). This helps us get a feel for the data before diving into cleaning and analysis.<b>

# %%
unemp.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
unemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
unemp.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
unemp.shape
# Out:
# (768, 7)

# %% [markdown]
# #### <b>:- Next, we’ll clean the data to make it ready for analysis. This includes handling missing values, removing duplicates, fixing inconsistent entries, and ensuring all columns have the correct data types. Cleaning the data helps ensure our analysis is accurate and the visualizations are meaningful.<b>

# %%
unemp = unemp.drop_duplicates()

# %%
#Remove any leading spaces from column names to avoid errors (e.g., " Date " → "Date")
unemp.columns = unemp.columns.str.strip()

# %%
unemp['Date'] = pd.to_datetime(unemp['Date'], errors='coerce', dayfirst=True)

# %%
# Check how many missing (NaN) values are present in each column
unemp.isnull().sum()
# Out:
# Region                                     1
# Date                                       1
# Frequency                                  1
# Estimated Unemployment Rate (%)            1
# Estimated Employed                         1
# Estimated Labour Participation Rate (%)    1
# Area                                       1
# dtype: int64

# %%
#Drop all rows that contain any missing (NaN) values from the DataFrame, updating it in place
unemp.dropna(inplace=True)

# %%
unemp.isnull().sum()
#Now we have 0 null values
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %% [markdown]
# #### <b>:- Next, we’ll perform Exploratory Data Analysis (EDA) to dive into our data and understand it better. Using charts, plots, and summary statistics, we’ll identify trends, spot anomalies, and see how unemployment varies across states and over time. EDA helps us uncover the key patterns hidden in the data.<b>

# %% [markdown]
# <b>Here, we visualize the average unemployment rates across different regions (states/UTs) to compare regional trends. Using a bar plot, we can easily see which regions have higher or lower unemployment. The colored bars and rotated labels make the chart more readable, helping us quickly identify patterns and regional differences in unemployment.<b>

# %%
plt.figure(figsize=(15, 7))
color=["#FF9933", "#138808"]
sns.barplot(x="Region", y="Estimated Unemployment Rate (%)", data=unemp, ci=None,  palette=color)
plt.xticks(rotation=90)
plt.title("Unempolyement Rate by Region")
plt.xlabel("Reagion")
plt.ylabel("Unemployment Rate (%)")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\4000609402.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Region", y="Estimated Unemployment Rate (%)", data=unemp, ci=None,  palette=color)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\4000609402.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Region", y="Estimated Unemployment Rate (%)", data=unemp, ci=None,  palette=color)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\4000609402.py:3: UserWarning:
# The palette list has fewer values (2) than needed (28) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="Region", y="Estimated Unemployment Rate (%)", data=unemp, ci=None,  palette=color)

# %% [markdown]
# <b>In this step, we use a box plot to explore the distribution and variation of labor participation rates across different regions. The plot highlights the spread, median, and potential outliers, giving us a clear view of how workforce participation differs regionally. This helps identify areas with unusually high or low participation rates.<b>

# %%
plt.figure(figsize=(12, 6))
color=["#FF9933", "#138808"]
sns.boxplot(x="Region", y="Estimated Labour Participation Rate (%)", data=unemp, palette=color)
plt.title("Labor Participation Rate by Region")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\1375833737.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Region", y="Estimated Labour Participation Rate (%)", data=unemp, palette=color)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\1375833737.py:3: UserWarning:
# The palette list has fewer values (2) than needed (28) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x="Region", y="Estimated Labour Participation Rate (%)", data=unemp, palette=color)

# %% [markdown]
# <b>Here, we calculate the average unemployment rate and labor participation rate for each region. By summarizing these key metrics, we can easily compare how different regions are performing and identify areas with higher unemployment or lower workforce participation.<b>

# %%
avg_metrics = unemp.groupby('Region')[['Estimated Unemployment Rate (%)', 'Estimated Labour Participation Rate (%)']].mean()

# %%
avg_metrics
# Out:
#                   Estimated Unemployment Rate (%)  \
# Region
# Andhra Pradesh                           7.477143
# Assam                                    6.428077
# Bihar                                   18.918214
# Chandigarh                              15.991667
# Chhattisgarh                             9.240357
# Delhi                                   16.495357
# Goa                                      9.274167
# Gujarat                                  6.663929
# Haryana                                 26.283214
# Himachal Pradesh                        18.540357
# Jammu & Kashmir                         16.188571
# Jharkhand                               20.585000
# Karnataka                                6.676071
# Kerala                                  10.123929
# Madhya Pradesh                           7.406429
# Maharashtra                              7.557500
# Meghalaya                                4.798889
# Odisha                                   5.657857
# ...

# %% [markdown]
# <b>In this step, we create a bar chart to compare regions based on their average unemployment and labor participation rates. The plot makes it easy to see which regions are struggling with higher unemployment or lower workforce participation, providing a clear visual comparison across all regions.<b>

# %%
avg_metrics.sort_values(by="Estimated Unemployment Rate (%)", ascending=False).plot(
    kind="bar", figsize=(12, 6),
    # Saffron & Green
    color=["#FF9933", "#138808"])
plt.title("Average Unemployment and Labor Participation Rate by Region", fontsize=14, fontweight="bold")
plt.ylabel("Percentage")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Here, we explore the distribution of records between Urban and Rural areas. Using a count plot, we can quickly see how much data comes from each area type, helping us understand the dataset’s balance and regional coverage.<b>

# %%
unemp["Area"].value_counts()
color=["#FF9933", "#138808"]
sns.countplot(x="Area",data=unemp, palette=color)
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11676\1300273186.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Area",data=unemp, palette=color)

# %% [markdown]
# <b>Here, we’re examining how the unemployment rate, number of employed, and labor participation rate relate to each other. Using pairwise scatterplots with density plots on the diagonal, we can spot correlations, trends, and patterns between these key workforce metrics, helping us understand their interactions more clearly.<b>

# %%
pair_data = unemp[["Estimated Unemployment Rate (%)", "Estimated Employed", 
                   "Estimated Labour Participation Rate (%)"]]
sns.pairplot(pair_data, diag_kind="kde", markers="o")
plt.suptitle("Relationship Between Key Metrics", y=1)
plt.show()

# %% [markdown]
# ### <b>:- In this section, we focus on analyzing the unemployment rate data up to November 2020. This includes examining trends over time, identifying peaks and dips, and understanding how events like COVID-19 impacted unemployment across different states and regions. The goal is to uncover insights that show how the labor market evolved during this period.<b>

# %% [markdown]
# <b>Now, we’re going to explore the unemployment rate data up to November 2020, including the period impacted by COVID-19, to understand it better. We’ll check the size of the dataset with .shape, look at the first few rows with .head(), inspect data types and missing values using .info(), and get a quick statistical summary with .describe(). This step helps us get a clear picture of the data, including how the pandemic affected unemployment trends, before moving on to cleaning and deeper analysis.<b>

# %%
unemp_rate.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
unemp_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
unemp_rate.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
unemp_rate.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
unemp_rate.columns = unemp_rate.columns.str.strip()

# %%
unemp_rate.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
unemp_rate.shape
# Out:
# (267, 9)

# %% [markdown]
# <b>Here, we rename the columns of the unemp_rate DataFrame to make them consistent, clear, and easier to work with. Clear column names help avoid confusion during analysis and make it simpler to reference specific data points in subsequent steps.<b>

# %%
unemp_rate.columns= ["States","Date","Frequency",
               "Estimated Unemployment Rate",
               "Estimated Employed",
               "Estimated Labour Participation Rate",
               "Region","longitude","latitude"]

# %%
unemp_rate.columns
# Out:
# Index(['States', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Region',
#        'longitude', 'latitude'],
#       dtype='object')

# %%
# Convert the 'Date' column to datetime format  
# If any invalid date is found, it will be replaced with NaT (Not a Time) instead of raising an error  
unemp_rate['Date'] = pd.to_datetime(unemp_rate['Date'], errors='coerce',dayfirst=True)

# %%
unemp_rate = unemp_rate.dropna(subset=['Date'])

# %% [markdown]
# <b>Filtering the dataset to only include records from the year 2020.
# This helps in focusing on the unemployment trends during the Covid-19 period, allowing us to analyze how the pandemic impacted the labor market.<b>

# %%
covid_data = unemp_rate[unemp_rate['Date'].dt.year == 2020]

# %%
covid_data
# Out:
#              States       Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# ..              ...        ...       ...                          ...
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
# 264     West Bengal 2020-08-31         M                        14.87
# 265     West Bengal 2020-09-30         M                         9.35
# 266     West Bengal 2020-10-31         M                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region  \
# ...

# %% [markdown]
# ### Q1: Visualizing the overall unemployment trend during COVID-19 in 2020

# %% [markdown]
# **:- Using a line plot to show how unemployment rates changed over time**
# **:- 'hue=Region' adds separate lines for each region, making comparisons easier**
# **:- Grid is enabled for better readability of values**

# %%
plt.figure(figsize=(12, 6))
colors = ["#FF9933", "#FFD700", "#138808", "#000080", "#1CA9C9"]
sns.lineplot(data=covid_data, x='Date', y='Estimated Unemployment Rate', hue='Region', palette=colors)
plt.title("Trend of Unemployment Rate During COVID-19 (2020)")
plt.xlabel("Date")
plt.ylabel("Estimated Unemployment Rate (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q2: Visualizing which regions faced the highest unemployment impact during COVID-19 (2020)

# %% [markdown]
# **Using a boxplot to compare unemployment rate distribution across regions**

# %%
plt.figure(figsize=(10, 6))
colors = ["#FF9933", "#138808","#000080", "#FF8000", "#006400"]  
sns.boxplot(data=covid_data, x='Region', y='Estimated Unemployment Rate', palette=colors)
plt.title("Unemployment Rate by Region During COVID-19 (2020)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19408\1974141793.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=covid_data, x='Region', y='Estimated Unemployment Rate', palette=colors)

# %% [markdown]
# ### Q3: Were there any seasonal trends in unemployment during the pandemic?

# %%
covid_data['Month'] = covid_data['Date'].dt.month
monthly_avg = covid_data.groupby('Month')['Estimated Unemployment Rate'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x='Month', y='Estimated Unemployment Rate', data=monthly_avg, marker='o', color="#E97451")
plt.title("Seasonal Trends in Unemployment Rate During COVID-19 (2020)")
plt.xlabel("Month")
plt.ylabel("Average Unemployment Rate (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q4: States most impacted by unemployment during COVID-19

# %%
state_avg = covid_data.groupby('States')['Estimated Unemployment Rate'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=state_avg.values, y=state_avg.index,  palette='viridis')
plt.title("Top 10 States Most Impacted by Unemployment During COVID-19 (2020)")
plt.xlabel("Average Unemployment Rate (%)")
plt.ylabel("States")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19408\2371015671.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_avg.values, y=state_avg.index,  palette='viridis')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### 1:- Unemployment Trends: Northern and Eastern regions have higher unemployment rates, indicating potential regional inequalities.

# %% [markdown]
# #### 2:- Labor Participation: Labor participation rate and unemployment rate are inversely related in most cases, showing that increasing workforce participation is vital.

# %% [markdown]
# #### 3:- COVID-19 Impact: The pandemic caused a sharp rise in unemployment across all regions, with some states and regions being disproportionately affected. Economic recovery was uneven, with certain states taking longer to stabilize.
